# %% [markdown]
# # Assignment 3
# - Assignment should be submitted as jupyter notebook, no other formats accepted
# - Your notebook file name should follow this format: Assignment_1_FirstName_LastName.ipynb
# - For each of the questions below, write your code in the cell below the question
# - Your code should run and generate expected outcome to receive full grade
# - Save your  notebook with your code included and upload to blackboard by the due date/time
# - Late submissions are not accepted
# - You can submit to blackboard multiple times, the last submission will be graded

# %% [markdown]
# ## Question 1 (30 points)
# Write a program that first gets a list of integers from input. The input begins with an integer indicating the number of integers that follow. Then, get the last value from the input, and output all integers less than or equal to that value.
#
# >Ex: If the input is:
# 05
# 50
# 60
# 140
# 200
# 75
# 100
#
# >the output is:
# 50
# 60
# 75
#
# The 5 indicates that there are five integers in the list, namely 50, 60, 140, 200, and 75. The 100 indicates that the program should output all integers less than or equal to 100, so the program outputs 50, 60, and 75.
#
# Such functionality is common on sites like Amazon, where a user can filter results.
#
# Your code must define and call the following two functions:
#
# def get_user_values()
# def output_ints_less_than_or_equal_to_threshold(user_values, upper_threshold)
#
# Utilizing functions will help to make your main very clean and intuitive.

# %%
#Defining the function to get input
def get_user_values():
    #Declaring variables and getting input
    num_list = []
    num = int(input())
    for i in range(5):
        temp = int(input())
        num_list.append(temp)
        
    return num_list

#Defining function for less than or equal to
def output_ints_less_than_or_equal_to_threshold(user_values, upper_threshold):
    #Returning values less than or equal to the value
    for i in user_values:
        if(i <= upper_threshold):
            print(i)

#Main
if __name__ == '__main__':
    #Declaring list and getting input
    numbers = get_user_values()
    upper_num = int(input())
    
    #Printing numbers less than or equal to upper num
    print()
    output_ints_less_than_or_equal_to_threshold(numbers, upper_num)
# Out:
# 5
# 50
# 60
# 140
# 200
# 75
# 100
#
# 50
# 60
# 75

# %% [markdown]
# ## Question 2 (70 points)
# Write a Python program that does following:
#
# (1) Prompt the user to enter a string of their choosing. Store the text in a string. Output the string.
#
# >Ex:
# Enter a sample text:
# we'll continue our quest in space.  there will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  nothing ends here;  our hopes and our journeys continue!
# You entered: we'll continue our quest in space.  there will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  nothing ends here;  our hopes and our journeys continue!
#
# (2) Implement a print_menu() function, which has a string as a parameter, outputs a menu of user options for analyzing/editing the string, and returns the user's entered menu option and the sample text string (which can be edited inside the print_menu() function). Each option is represented by a single character.
#
# If an invalid character is entered, continue to prompt for a valid choice.
# Hint: Implement the Quit menu option before implementing other options. Call print_menu() in the main section of your code. Continue to call print_menu() until the user enters q to Quit.
#
# >Ex:
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
#
# (3) Implement the get_num_of_non_WS_characters() function. get_num_of_non_WS_characters() has a string parameter and returns the number of characters in the string, excluding all whitespace. Call get_num_of_non_WS_characters() in the print_menu() function.
#
# >Ex:
# Number of non-whitespace characters: 181
#
# (4) Implement the get_num_of_words() function. get_num_of_words() has a string parameter and returns the number of words in the string. Hint: Words end when a space is reached except for the last word in a sentence. Call get_num_of_words() in the print_menu() function.
#
# >Ex:
# Number of words: 35
#
# (5) Implement the fix_capitalization() function. fix_capitalization() has a string parameter and returns an updated string, where lowercase letters at the beginning of sentences are replaced with uppercase letters. fix_capitalization() also returns the number of letters that have been capitalized. Call fix_capitalization() in the print_menu() function, and then output the the edited string followed by the number of letters capitalized. Hint 1: Look up and use Python functions .islower() and .upper() to complete this task. Hint 2: Create an empty string and use string concatenation to make edits to the string.
#
# >Ex:
# Number of letters capitalized: 3
# Edited text: We'll continue our quest in space.  There will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  Nothing ends here;  our hopes and our journeys continue!
#
#
# (6) Implement the replace_punctuation() function. replace_punctuation() has a string parameter and two keyword argument parameters exclamation_count and semicolon_count. replace_punctuation() updates the string by replacing each exclamation point (!) character with a period (.) and each semicolon (;) character with a comma (,). replace_punctuation() also counts the number of times each character is replaced and outputs those counts. Lastly, replace_punctuation() returns the updated string. Call replace_punctuation() in the print_menu() function, and then output the edited string.
#
# >Ex:
# Punctuation replaced
# exclamation_count: 1
# semicolon_count: 2
# Edited text: we'll continue our quest in space.  there will be more shuttle flights and more shuttle crews and,  yes,  more volunteers, more civilians,  more teachers in space.  nothing ends here,  our hopes and our journeys continue.
#
# (7) Implement the shorten_space() function. shorten_space() has a string parameter and updates the string by replacing all sequences of 2 or more spaces with a single space. shorten_space() returns the string. Call shorten_space() in the print_menu() function, and then output the edited string. Hint: Look up and use Python function .isspace().
#
# >Ex:
# Edited text: we'll continue our quest in space. there will be more shuttle flights and more shuttle crews and, yes, more volunteers, more civilians, more teachers in space. nothing ends here; our hopes and our journeys continue!

# %%
#Importing for string space function
import re

def print_menu(user_str):
    #Defining variables
    c_str = 'c - Number of non-whitespace characters\n'
    w_str = 'w - Number of words\n'
    f_str = 'f - Fix capitalization\n'
    r_str = 'r - Replace punctuation\n'
    s_str = 's - Shorten spaces\n'
    q_str = 'q - Quit\n'
    menu = '\nMENU\n' + c_str + w_str + f_str + r_str + s_str + q_str + 'Choose an option:'
    print(menu)
    
    #Getting menu option
    menu_op = input()
    
    #Testing for menu options
    if(menu_op == 'c'):
        tot = get_num_of_non_WS_characters(user_str)
        print(f'Number of non-whitespace characters: {tot}')
    elif(menu_op == 'w'):
        tot = get_num_of_words(user_str)
        print(f'Number of words: {tot}')
    elif(menu_op == 's'):
        user_str = shorten_space(user_str)
        print('Edited text: ' + user_str)
    elif(menu_op == 'f'):
        user_str, tot = fix_capitalization(user_str)
        print(f'Number of letters capitalized: {tot}')
        print('Edited string: ' + user_str)
    elif(menu_op == 'r'):
        user_str, excl, semi = replace_punctuation(user_str)
        print('Punctuation replaced')
        print(f'Exclamation count: {excl}')
        print(f'Semicolon count: {semi}')
        print('Edited text: ' + user_str)
    
    return menu_op, user_str

#Defining non WS character count
def get_num_of_non_WS_characters(string):
    #Testing for white spaces
    #temp = 0
    #while(temp == 0):
    #    if(' ' in string):
    #        string = string.replace(' ', '')
    #    else:
    #        temp = 1
    string = shorten_space(string)
    string = string.replace(' ', '')
    
    total_char = len(string)
    return total_char

#Defining word count
def get_num_of_words(string):
    new_str = shorten_space(string)
    tot_word = len(new_str.strip().split(' '))
    return tot_word

#Creating shorten space
def shorten_space(string):
    new_str = ''
    for i in range(len(string)):
        if(i != len(string)):
            if(string[i] == ' ' and (string[i+1]) == ' '):
                continue
        new_str += string[i]
    return new_str

#Creating capitalization fix
def fix_capitalization(string):
    new_str = ''
    count = 0
    temp = string.split('. ')
    
    for i in temp:
        if any(e in i for e in ['!', '?', '.']):
            if i[0].islower():
                new_str += i[0].upper() + i[1:]
                count += 1
            elif i[0] == ' ':
                if i[1].islower():
                    new_str += ' ' + i[1].upper() + i[2:]
                    count += 1
                else:
                    new_str += i
            else:
                new_str += i
        else:
            if i[0].islower():
                new_str += i[0].upper() + i[1:]
                count += 1
            elif i[0] == ' ':
                if i[1].islower():
                    new_str += ' ' + i[1].upper() + i[2:]
                    count += 1
                else:
                    new_str += i
            else:
                new_str += i
            new_str += '. '
            
    return new_str, count

#Creating replace punctuation
def replace_punctuation(string):
    new_str = ''
    excl_count = 0
    semi_count = 0
    for i in string:
        if(i == '!'):
            new_str += '.'
            excl_count += 1
        elif(i == ';'):
            new_str += ','
            semi_count += 1
        else:
            new_str += i
    
    return new_str, excl_count, semi_count

if __name__ == '__main__':
    #Getting input
    string = input('Enter a sample text: ')
    print('You entered: ' + string)
    
    while(option != 'q'):
        option, string = print_menu(string)
# Out:
# Enter a sample text: we'll continue our quest in space.  there will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  nothing ends here;  our hopes and our journeys continue!
# You entered: we'll continue our quest in space.  there will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  nothing ends here;  our hopes and our journeys continue!
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# c
# Number of non-whitespace characters: 181
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# w
# Number of words: 35
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# f
# Number of letters capitalized: 3
# Edited string: We'll continue our quest in space.  There will be more shuttle flights and more shuttle crews and,  yes;  more volunteers, more civilians,  more teachers in space.  Nothing ends here;  our hopes and our journeys continue!
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# r
# Punctuation replaced
# Exclamation count: 1
# Semicolon count: 2
# Edited text: We'll continue our quest in space.  There will be more shuttle flights and more shuttle crews and,  yes,  more volunteers, more civilians,  more teachers in space.  Nothing ends here,  our hopes and our journeys continue.
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# s
# Edited text: We'll continue our quest in space. There will be more shuttle flights and more shuttle crews and, yes, more volunteers, more civilians, more teachers in space. Nothing ends here, our hopes and our journeys continue.
#
# MENU
# c - Number of non-whitespace characters
# w - Number of words
# f - Fix capitalization
# r - Replace punctuation
# s - Shorten spaces
# q - Quit
# Choose an option:
# q
